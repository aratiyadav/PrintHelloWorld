# %% [markdown]
# # Implementing Graph Theory
# <li>Create a nice looking graph of the political blog network
# <li>What are the 10 most influential blogs?
# <li>What are the 10 least influential blogs?
# <li>Answer this question for both left wing and right wing blogs seperately. (Optional 10 Extra Credit Points)

# %%
import networkx as nx
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
M=nx.read_gml("/Users/Arati/Documents/UIS/FALL2016/DataScience/PythonPrograms/CS570-master/polblogs.gml")

# %%
# create weighted graph from M
G = nx.Graph()
for u,v,data in M.edges_iter(data=True):
    if G.has_edge(u,v):
        G[u][v]['weight'] += 1
    else:
        G.add_edge(u, v, weight=1)

# %%
plt.figure(figsize=(40,40))
pos=nx.spring_layout(M, iterations=500, scale=5, k=.3)
nx.draw_networkx_labels(M,pos,fontsize=8)
font = {'fontname'   : 'Helvetica',
            'color'      : 'k',
            'fontweight' : 'bold',
            'fontsize'   : 14}
plt.title("Political Blog Network", font)


nx.draw_networkx_nodes(M,pos,node_color='b',alpha=0.4)
nx.draw_networkx_edges(M,pos,alpha=0.4,node_size=0,width=1,edge_color='k')
plt.axis('off')
plt.show()
# Out:
# //anaconda/lib/python3.5/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family ['Helvetica'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#WHAT ARE THE TEN MOST INFLUENTIAL POLITICAL BLOGS

# %%
centrality=nx.eigenvector_centrality(M)

# %%
political_blog_list = []
for node in centrality:
    political_blog_list.append((node,centrality[node]))
    
sorted_political_blog_list = political_blog_list.sort(key=lambda x: x[1])

# %%
sorted(political_blog_list, key=lambda x: x[1], reverse=True)
# Out:
# [('atrios.blogspot.com', 0.23426536453043312),
#  ('dailykos.com', 0.21639707251498333),
#  ('talkingpointsmemo.com', 0.2103485182735518),
#  ('washingtonmonthly.com', 0.18777229295880862),
#  ('talkleft.com', 0.16161261819865713),
#  ('prospect.org/weblog', 0.15653698380607953),
#  ('juancole.com', 0.15571213713632828),
#  ('digbysblog.blogspot.com', 0.15103212988144987),
#  ('pandagon.net', 0.14609601532480007),
#  ('yglesias.typepad.com/matthew', 0.14335303565339647),
#  ('j-bradford-delong.net/movable_type', 0.14308133631248615),
#  ('tbogg.blogspot.com', 0.13456983252135007),
#  ('crookedtimber.org', 0.13070782213301393),
#  ('rittenhouse.blogspot.com', 0.13060603872174925),
#  ('maxspeak.org/mt', 0.12830923072052522),
#  ('reachm.com/amstreet', 0.12639648860429942),
#  ('bodyandsoul.typepad.com', 0.12397669105391176),
#  ('dneiwert.blogspot.com', 0.12053325188718592),
#  ('thismodernworld.com', 0.11910334969940801),
#  ('oliverwillis.com', 0.11695770006400431),
# ...

# %%
#WHAT ARE THE TEN LEAST INFLUENTIAL POLITICAL BLOGS

# %%
sorted(political_blog_list, key=lambda x: x[1], reverse=False)
# Out:
# [('40ozblog.blogspot.com', 0.0),
#  ('4lina.tblog.com', 0.0),
#  ('84rules.blog-city.com', 0.0),
#  ('95theses.blogspot.com', 0.0),
#  ('a100wwe.blogspot.com', 0.0),
#  ('absurd-canadian.blogspot.com', 0.0),
#  ('achingandspinning.blogspot.com', 0.0),
#  ('adamtalib.blogspot.com', 0.0),
#  ('adonai.cc', 0.0),
#  ('airjun.blogspot.com', 0.0),
#  ('alamodispatches.blogspot.com', 0.0),
#  ('aldaron.modblog.com', 0.0),
#  ('alternateworlds.blogspot.com', 0.0),
#  ('americaindenial.com/?q=node/feed', 0.0),
#  ('americancommentator.blogs.com/the_american_commentator_', 0.0),
#  ('americandreamslost.blogspot.com', 0.0),
#  ('americanjihad.blogspot.com', 0.0),
#  ('americankernel.com', 0.0),
#  ('americanmuslim.blogs.com', 0.0),
#  ('americasteen.tk', 0.0),
#  ('amradio.blogspot.com', 0.0),
#  ('anothervrwc.blogspot.com', 0.0),
#  ('anybodybutbushyall.blogspot.com', 0.0),
#  ('asian-nation.org/headlines/index.php', 0.0),
#  ('asiegeofherons.blogspot.com', 0.0),
# ...
