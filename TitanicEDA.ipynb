# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/Arati/Documents/UIS/FALL2016/DataScience/DataSet/train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ###EDA
#
# Learn about data!
#
# For each variable:
#     <li>Is it categorical?
#     <li>If not Min,Max,Avg vaues?
#     <li>If it is what are the categories?
#     <li>are there missing values?
#     <li>something about the distribution of the variable

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts().plot(kind='bar')
# Out:
# //anaconda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# //anaconda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
df.Sex.value_counts().plot(kind='bar')

# %%
df.Sex.value_counts().plot(kind='bar')

# %%
df(df.Sex=='female')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-90fdd914c37f> in <module>()
# ----> 1 df(df.Sex=='female')
#
# TypeError: 'DataFrame' object is not callable

# %%
df[df.Sex=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 19            20         1       3
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 49            50         0       3
# ...

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 26.5500     15
# 7.2292      15
# 0.0000      15
# 7.2500      13
# 7.8542      13
# 8.6625      13
# 7.2250      12
# 9.5000       9
# 16.1000      9
# 24.1500      8
# 15.5000      8
# 56.4958      7
# 14.5000      7
# 7.0500       7
# 52.0000      7
# 31.2750      7
# 69.5500      7
# 14.4542      7
# 7.7958       6
# 26.2500      6
# 30.0000      6
# 27.9000      6
#             ..
# 211.5000     1
# 12.2750      1
# 8.6542       1
# 6.9500       1
# 22.0250      1
# 7.1417       1
# 10.1708      1
# 17.4000      1
# 8.3000       1
# 16.0000      1
# 10.5167      1
# 15.0458      1
# 50.4958      1
# 8.4042       1
# 26.2833      1
# 12.6500      1
# 8.7125       1
# 22.5250      1
# 15.7500      1
# 9.2167       1
# 21.6792      1
# 14.1083      1
# 15.1000      1
# 7.3125       1
# 8.1125       1
# 13.8583      1
# 34.6542      1
# ...

# %%
df.describe()
# Out:
# //anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# ...

# %%
    df.Fare.hist()

# %%
df[df.Fare==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
df.PassengerId.count()
# Out:
# 891

# %%
df.Survived.count('1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-5012f041d4c7> in <module>()
# ----> 1 df.Survived.count('1')
#
# //anaconda/lib/python3.5/site-packages/pandas/core/series.py in count(self, level)
#    1175
#    1176         if isinstance(level, compat.string_types):
# -> 1177             level = self.index._get_level_number(level)
#    1178
#    1179         lev = self.index.levels[level]
#
# //anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in _get_level_number(self, level)
#    1167
#    1168     def _get_level_number(self, level):
# -> 1169         self._validate_index_level(level)
#    1170         return 0
#    1171
#
# //anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in _validate_index_level(self, level)
#    1164         elif level != self.name:
#    1165             raise KeyError('Level %s must be same as name (%s)' %
# ...
