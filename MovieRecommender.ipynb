# %%
import pandas as pd
import numpy as np
import random
import time

# %%
M = pd.read_csv("/Users/Arati/Documents/UIS/FALL2016/DataScience/DataSet/MovieReviews.csv")

# %%
M.head()
# Out:
#            Unnamed: 0  American Sniper  The Hunger Games: Mockingjay - Part 1  \
# 0       Aarti Jaiswal              4.0                                    NaN
# 1  Aditya Dharmasagar              5.0                                    NaN
# 2   Adrian Cavallaris              NaN                                    4.0
# 3   Ahmed Muheebuddin              5.0                                    NaN
# 4     Aishwarya reddy              NaN                                    3.0
#
#    Guardians of the Galaxy  The Lego Movie  The Hobbit  Transformers  \
# 0                      NaN             NaN         4.0           3.0
# 1                      NaN             4.0         5.0           4.0
# 2                      3.0             NaN         4.0           2.0
# 3                      4.0             NaN         3.0           NaN
# 4                      4.0             3.0         4.0           4.0
#
#    Malificent  Big Hero 6  Godzilla  Interstellar  How to Train your Dragon 2  \
# ...

# %%
M.rename(columns={'Unnamed: 0':'Name'}, inplace=True)

# %%
M
# Out:
#                    Name  American Sniper  \
# 0         Aarti Jaiswal              4.0
# 1    Aditya Dharmasagar              5.0
# 2     Adrian Cavallaris              NaN
# 3     Ahmed Muheebuddin              5.0
# 4       Aishwarya reddy              NaN
# 5              Akhilesh              NaN
# 6           Andrew Webb              4.0
# 7               Anirudh              3.0
# 8         Anirudh Thota              NaN
# 9                anurag              4.0
# 10         Anusha Putta              NaN
# 11          Arun Vedere              4.0
# 12      Ashutosh Sureka              5.0
# 13         Aswini kumar              4.0
# 14                 azam              4.0
# 15   Benjamin Baysinger              5.0
# 16       Bhuvana Posina              5.0
# 17     Bradley Brubaker              NaN
# 18       Brant Mullinix              NaN
# 19              Charlie              NaN
# 20          David Huang              5.0
# 21        David Reyling              NaN
# ...

# %%
M = M.pivot_table(index=['Name'])

# %%
M.columns
# Out:
# Index(['300: Rise of an Empire', 'American Sniper', 'Big Hero 6', 'Divergent',
#        'Godzilla', 'Gone Girl', 'Guardians of the Galaxy',
#        'How to Train your Dragon 2', 'Interstellar', 'Malificent',
#        'The Fault in Our Stars', 'The Hobbit',
#        'The Hunger Games: Mockingjay - Part 1', 'The Lego Movie',
#        'Transformers', 'Unbroken'],
#       dtype='object')

# %%
M
# Out:
#                              300: Rise of an Empire  American Sniper  \
# Name
# Aarti Jaiswal                                   NaN              4.0
# Aditya Dharmasagar                              5.0              5.0
# Adrian Cavallaris                               NaN              NaN
# Ahmed Muheebuddin                               NaN              5.0
# Aishwarya reddy                                 3.0              NaN
# Akhilesh                                        5.0              NaN
# Aman Chandrakar                                 3.0              4.0
# Amy Camp                                        NaN              3.0
# Andrew Peabody                                  NaN              NaN
# Andrew Webb                                     3.0              4.0
# Anirudh                                         2.0              3.0
# Anirudh Thota                                   4.0              NaN
# ...

# %%
def pearson(s1, s2):
    """Take two pd.Series objects and return a pearson correlation."""
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    return np.sum(s1_c * s2_c) / np.sqrt(np.sum(s1_c ** 2) * np.sum(s2_c ** 2))

# %%
pearson(M['American Sniper'], M['The Hunger Games: Mockingjay - Part 1'])
# Out:
# -0.057776749637220445

# %%
pearson(M['The Fault in Our Stars'], M['The Hunger Games: Mockingjay - Part 1'])
# Out:
# 0.0035860477297098097

# %%
def get_recs(movie_name, M, num):

    import numpy as np
    
    reviews = []
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
    
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %%
###Question 1: What movie is most Similar to 'The fault in our stars' (60 pts)
recs = get_recs('The Fault in Our Stars', M, 10)

# %%
recs[:10]
# Out:
# [('Malificent', 0.23991673898891641),
#  ('Divergent', 0.22877381394629401),
#  ('Interstellar', 0.19474772166784537),
#  ('Gone Girl', 0.16101481946028828),
#  ('Godzilla', 0.1329024802056645),
#  ('How to Train your Dragon 2', 0.10490531013219508),
#  ('Unbroken', 0.096104184726738318),
#  ('Guardians of the Galaxy', 0.050843844134915404),
#  ('Transformers', 0.019473395239836135),
#  ('The Hunger Games: Mockingjay - Part 1', 0.0035860477297098097)]

# %%
anti_recs = get_recs('The Fault in Our Stars', M, 8551)

# %%
anti_recs[-10:]
# Out:
# [('How to Train your Dragon 2', 0.10490531013219508),
#  ('Unbroken', 0.096104184726738318),
#  ('Guardians of the Galaxy', 0.050843844134915404),
#  ('Transformers', 0.019473395239836135),
#  ('The Hunger Games: Mockingjay - Part 1', 0.0035860477297098097),
#  ('The Lego Movie', 0.0033828058596859821),
#  ('The Hobbit', -0.0067811793831179783),
#  ('300: Rise of an Empire', -0.061088521306081077),
#  ('Big Hero 6', -0.1455844309691561),
#  ('American Sniper', -0.15882227338568652)]

# %%
###Question 2: Which movie(s) would you most like to see, based on your classmates experience? (40 p)

# %%
#HINTS...

#the movies I've seen
my_ratings = M.ix['Aarti Jaiswal'].dropna()
#the movie I've rated the highest
my_ratings.sort(ascending=False)
#the name of the movie I've rated the highest
fav_movie = my_ratings.index[0]
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:6: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting

# %%
fav_movie
# Out:
# 'Big Hero 6'

# %%
recs = get_recs('Big Hero 6', M, 10)

# %%
recs
# Out:
# [('The Lego Movie', 0.20901553983354043),
#  ('Guardians of the Galaxy', 0.18598890410520871),
#  ('How to Train your Dragon 2', 0.17090205507315112),
#  ('The Hunger Games: Mockingjay - Part 1', 0.14522493178292423),
#  ('Transformers', 0.11962672699512181),
#  ('The Hobbit', 0.11066615098001192),
#  ('American Sniper', 0.050162287833357182),
#  ('Unbroken', 0.050131216544802959),
#  ('Divergent', -0.011563173968017563),
#  ('300: Rise of an Empire', -0.053658313346331282)]
